# %%
# !wget https://raw.githubusercontent.com/NastiaSheffka/comp-ling/refs/heads/main/crime_and_punishment.txt
# Out:
# --2024-11-17 09:32:57--  https://raw.githubusercontent.com/NastiaSheffka/comp-ling/refs/heads/main/crime_and_punishment.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1292321 (1.2M) [text/plain]
# Saving to: ‘crime_and_punishment.txt’
#
# crime_and_punishmen 100%[===================>]   1.23M  --.-KB/s    in 0.01s
#
# 2024-11-17 09:32:57 (114 MB/s) - ‘crime_and_punishment.txt’ saved [1292321/1292321]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict
import re

# %%
file_path = 'crime_and_punishment.txt'

# %%
with open(file_path, 'r', encoding='utf-8') as file:
  text = file.read()

# %%
text = text.lower()
text[500:1000]
# Out:
# 'at, for its excruciating suspense, its atmospheric vividness, and its depth of characterization and vision is almost unequaled in the literatures of the world. the best known of dostoevsky’s masterpieces,crime and punishment can bear any amount of rereading without losing a drop of its power over our imaginations. award-winning translators richard pevear and larissa volokhonsky render this elusive and wildly innovative novel with an energy, suppleness, and range of voice that do full justice to '

# %%
text = re.sub(r'[^a-z\s\.\?!]', '', text)
text[500:1000]
# Out:
# 's excruciating suspense its atmospheric vividness and its depth of characterization and vision is almost unequaled in the literatures of the world. the best known of dostoevskys masterpiecescrime and punishment can bear any amount of rereading without losing a drop of its power over our imaginations. awardwinning translators richard pevear and larissa volokhonsky render this elusive and wildly innovative novel with an energy suppleness and range of voice that do full justice to the genius of its'

# %%
sentences = re.split(r'[\.\?!]', text)
sentences[1:3]
# Out:
# [' raskolnikov an impoverished student living in the st',
#  ' petersburg of the tsars is determined to overreach his humanity and assert his untrammeled individual will']

# %%
sentences = [sentence.split() for sentence in sentences if sentence]
sentences[3]
# Out:
# ['when',
#  'he',
#  'commits',
#  'an',
#  'act',
#  'of',
#  'murder',
#  'and',
#  'theft',
#  'he',
#  'sets',
#  'into',
#  'motion',
#  'a',
#  'story',
#  'that',
#  'for',
#  'its',
#  'excruciating',
#  'suspense',
#  'its',
#  'atmospheric',
#  'vividness',
#  'and',
#  'its',
#  'depth',
#  'of',
#  'characterization',
#  'and',
#  'vision',
#  'is',
#  'almost',
#  'unequaled',
#  'in',
#  'the',
#  'literatures',
#  'of',
#  'the',
#  'world']

# %%
co_occurrence = defaultdict(lambda: defaultdict(int))

# %%
def update_co_occurrence(sentence, window_size=1):
    words = ["<START>"] + sentence + ["<END>"]
    for i, word in enumerate(words):
        for j in range(max(0, i - window_size), min(len(words), i + window_size + 1)):
            if i != j:
                co_occurrence[word][words[j]] += 1

for sentence in sentences:
    update_co_occurrence(sentence)
# Out:
# defaultdict(int,
#             {'dostoevsky': 4,
#              'and': 30,
#              'work': 2,
#              'of': 8,
#              'on': 10,
#              'in': 6,
#              'his': 14,
#              '<START>': 8,
#              'a': 14,
#              'an': 2,
#              '<END>': 34,
#              'yet': 2,
#              'for': 2,
#              'means': 2,
#              'every': 4,
#              'as': 10,
#              'rational': 2,
#              'does': 2,
#              'little': 2,
#              'the': 28,
#              'is': 6,
#              'itself': 6,
#              'or': 4,
#              'somehow': 2,
#              'that': 6,
#              'has': 4,
#              'known': 2,
#              'i': 2,
#              'against': 2,
#              'to': 4,
#              'at': 2,
#              'sir': 2,
#              'your': 4,
#              'will': 2,
#              'supposedly': 2,
#              'what': 2,
#              'sides': 2,
#              'my': 2,
#              'committed': 2,
#              'were': 2,
#              'even': 2})

# %%
co_occurrence['crime']
# Out:
# defaultdict(int,
#             {'dostoevsky': 4,
#              'and': 30,
#              'work': 2,
#              'of': 8,
#              'on': 10,
#              'in': 6,
#              'his': 14,
#              '<START>': 8,
#              'a': 14,
#              'an': 2,
#              '<END>': 34,
#              'yet': 2,
#              'for': 2,
#              'means': 2,
#              'every': 4,
#              'as': 10,
#              'rational': 2,
#              'does': 2,
#              'little': 2,
#              'the': 28,
#              'is': 6,
#              'itself': 6,
#              'or': 4,
#              'somehow': 2,
#              'that': 6,
#              'has': 4,
#              'known': 2,
#              'i': 2,
#              'against': 2,
#              'to': 4,
#              'at': 2,
#              'sir': 2,
#              'your': 4,
#              'will': 2,
#              'supposedly': 2,
#              'what': 2,
#              'sides': 2,
#              'my': 2,
#              'committed': 2,
#              'were': 2,
#              'even': 2})

# %%
co_occurrence['punishment']
# Out:
# defaultdict(int,
#             {'and': 8,
#              'dostoevskys': 2,
#              'can': 2,
#              'foreword': 2,
#              '<END>': 2,
#              'a': 2,
#              'for': 4,
#              'there': 2})

# %%
tokens = list(co_occurrence.keys())
tokens[:10]
# Out:
# ['<START>',
#  'genre',
#  'proseclassic',
#  'author',
#  'info',
#  'fyodor',
#  'dostoevsky',
#  'crime',
#  'and',
#  'punishment']

# %%
co_occurrence_df = pd.DataFrame(co_occurrence).fillna(0).astype(int).reindex(tokens, columns=tokens, fill_value=0)
co_occurrence_df
# Out:
#               <START>  genre  proseclassic  author  info  fyodor  dostoevsky  \
# <START>             0      2             0       0     0       2          24
# genre               2      0             2       0     0       0           0
# proseclassic        0      2             0       2     0       0           0
# author              0      0             2       0     2       0           0
# info                0      0             0       2     0       2           0
# ...               ...    ...           ...     ...   ...     ...         ...
# fortyday            0      0             0       0     0       0           0
# precedes            0      0             0       0     0       0           0
# accommodate         0      0             0       0     0       0           0
# kalatch             0      0             0       0     0       0           0
# looped              0      0             0       0     0       0           0
#
#               crime   and  punishment  ...  negated  antiidealist  teachers  \
# <START>           8  2046           0  ...        0             0         0
# genre             0     0           0  ...        0             0         0
# proseclassic      0     0           0  ...        0             0         0
# author            0     0           0  ...        0             0         0
# info              0     0           0  ...        0             0         0
# ...             ...   ...         ...  ...      ...           ...       ...
# fortyday          0     0           0  ...        0             0         0
# precedes          0     0           0  ...        0             0         0
# accommodate       0     0           0  ...        0             0         0
# kalatch           0     0           0  ...        0             0         0
# looped            0     0           0  ...        0             0         0
#
#               conditions  omsk  fortyday  precedes  accommodate  kalatch  \
# <START>                0     0         0         0            0        0
# genre                  0     0         0         0            0        0
# proseclassic           0     0         0         0            0        0
# author                 0     0         0         0            0        0
# info                   0     0         0         0            0        0
# ...                  ...   ...       ...       ...          ...      ...
# fortyday               0     0         0         0            0        0
# precedes               0     0         0         0            0        0
# accommodate            0     0         0         0            0        0
# kalatch                0     0         0         0            0        0
# looped                 0     0         0         0            0        0
#
#               looped
# <START>            0
# genre              0
# proseclassic       0
# author             0
# info               0
# ...              ...
# fortyday           0
# precedes           0
# accommodate        0
# kalatch            0
# looped             0
#
# [12293 rows x 12293 columns]
